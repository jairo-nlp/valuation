# %%
from analise import Analise

# %%
ativos_lista_simplificada = {
    'bancos': [
               'ITSA4.SA', 
               'BBDC4.SA', 
               'BBAS3.SA', 
               'SANB4.SA'
               ],
    'industrial': [
                   'WEGE3.SA', 
                   'TUPY3.SA', 
                   'MYPK3.SA', 
                   'SHUL4.SA'
                   ],
    'varejo': [
               'VVAR3.SA', 
               'BTOW3.SA', 
               'MGLU3.SA'
               ],
    'imobiliário': [
                    'TRIS3.SA', 
                    'ALSO3.SA', 
                    'MRVE3.SA', 
                    'EZTC3.SA', 
                    'TCSA3.SA',
                    'CYRE3.SA'],
    'saúde': [
              'AALR3.SA', 
              'FLRY3.SA', 
              'QUAL3.SA'
              ]
           }

ativos_lista_completa = {'Bens Industriais': ['ETER3.SA',
  'PTBL3.SA',
  'MILS3.SA',
  'EMBR3.SA',
  'FRAS3.SA',
  'POMO3.SA',
  'RAPT3.SA',
  'TUPY3.SA',
  'SHUL3.SA',
  'WEGE3.SA',
  'ROMI3.SA',
  'KEPL3.SA',
  'MTSA3.SA',
  'TASA3.SA',
  'AZUL3.SA',
  'GOLL3.SA',
  'RLOG3.SA',
  'RAIL3.SA',
  'LOGN3.SA',
  'JSLG3.SA',
  'TGMA3.SA',
  'ANHB3.SA',
  'CCRO3.SA',
  'ECNT3.SA',
  'ECOR3.SA',
  'ECOV3.SA',
  'CRBD3.SA',
  'TRIA3.SA',
  'TPIS3.SA',
  'VOES3.SA',
  'IVPR3.SA',
  'STBP3.SA',
  'WSON3.SA',
  'CARD3.SA',
  'ALPK3.SA',
  'PRNR3.SA',
  'VLID3.SA'],
 'Comunicações': ['ALGT3.SA', 'OIBR3.SA', 'TELB3.SA', 'VIVT3.SA', 'TIMP3.SA'],
 'Consumo Cíclico': ['CYRE3.SA',
  'DIRR3.SA',
  'EVEN3.SA',
  'EZTC3.SA',
  'GFSA3.SA',
  'HBOR3.SA',
  'JHSF3.SA',
  'JFEN3.SA',
  'MTRE3.SA',
  'MDNE3.SA',
  'MRVE3.SA',
  'PDGR3.SA',
  'RSID3.SA',
  'TCSA3.SA',
  'TEND3.SA',
  'TRIS3.SA',
  'VIVR3.SA',
  'CTNM3.SA',
  'DOHL3.SA',
  'CATA3.SA',
  'CTKA3.SA',
  'PTNT3.SA',
  'CTSA3.SA',
  'SGPS3.SA',
  'TEKA3.SA',
  'HGTX3.SA',
  'ALPA3.SA',
  'CAMB3.SA',
  'GRND3.SA',
  'VULC3.SA',
  'VIVA3.SA',
  'WHRL3.SA',
  'MYPK3.SA',
  'LEVE3.SA',
  'PLAS3.SA',
  'HOOT3.SA',
  'BKBR3.SA',
  'MEAL3.SA',
  'BMKS3.SA',
  'ESTR3.SA',
  'SHOW3.SA',
  'CVCB3.SA',
  'SMFT3.SA',
  'ANIM3.SA',
  'COGN3.SA',
  'SEER3.SA',
  'YDUQ3.SA',
  'RENT3.SA',
  'LCAM3.SA',
  'MOVI3.SA',
  'UNID3.SA',
  'SMLS3.SA',
  'ARZZ3.SA',
  'CEAB3.SA',
  'CGRA3.SA',
  'GUAR3.SA',
  'LLIS3.SA',
  'AMAR3.SA',
  'LREN3.SA',
  'MGLU3.SA',
  'VVAR3.SA',
  'BTOW3.SA',
  'CNTO3.SA',
  'LAME3.SA',
  'SLED3.SA'],
 'Consumo não Cíclico': ['AGRO3.SA',
  'SLCE3.SA',
  'TESA3.SA',
  'BSEV3.SA',
  'RESA3.SA',
  'SMTO3.SA',
  'BRFS3.SA',
  'JBSS3.SA',
  'MRFG3.SA',
  'BEEF3.SA',
  'CAML3.SA',
  'JOPA3.SA',
  'MDIA3.SA',
  'ODER3.SA',
  'ABEV3.SA',
  'NTCO3.SA',
  'BOBR3.SA',
  'CRFB3.SA',
  'PCAR3.SA'],
 'Financeiro': ['ABCB3.SA',
  'RPAD3.SA',
  'BRIV3.SA',
  'BAZA3.SA',
  'BMGB3.SA',
  'BIDI3.SA',
  'BPAN3.SA',
  'BEES3.SA',
  'BPAR3.SA',
  'BRSR3.SA',
  'BBDC3.SA',
  'BBAS3.SA',
  'BPAC3.SA',
  'IDVL3.SA',
  'ITSA3.SA',
  'ITUB3.SA',
  'BMEB3.SA',
  'BMIN3.SA',
  'PINE3.SA',
  'SANB3.SA',
  'CRIV3.SA',
  'BNDP3.SA',
  'GPIV3.SA',
  'IDNT3.SA',
  'B3SA3.SA',
  'CIEL3.SA',
  'BBSE3.SA',
  'IRBR3.SA',
  'PSSA3.SA',
  'SULA3.SA',
  'APER3.SA',
  'WIZS3.SA',
  'ALSO3.SA',
  'BRML3.SA',
  'BRPR3.SA',
  'GSHP3.SA',
  'IGBR3.SA',
  'IGTA3.SA',
  'JPSA3.SA',
  'LOGG3.SA',
  'MULT3.SA',
  'SCAR3.SA',
  'BBRK3.SA',
  'LPSB3.SA'],
 'Materiais Básicos': ['BRAP3.SA',
  'VALE3.SA',
  'FESA3.SA',
  'GGBR3.SA',
  'GOAU3.SA',
  'CSNA3.SA',
  'USIM3.SA',
  'PMAM3.SA',
  'BRKM3.SA',
  'ELEK3.SA',
  'GPCP3.SA',
  'FHER3.SA',
  'CRPG3.SA',
  'UNIP3.SA',
  'DTEX3.SA',
  'EUCA3.SA',
  'KLBN3.SA',
  'NEMO3.SA',
  'SUZB3.SA'],
 'Petróleo, Gás e Biocombustíveis': ['CSAN3.SA',
  'DMMO3.SA',
  'ENAT3.SA',
  'RPMG3.SA',
  'PETR3.SA',
  'BRDT3.SA',
  'PRIO3.SA',
  'UGPA3.SA',
  'LUPA3.SA',
  'OSXB3.SA'],
 'Saúde': ['GBIO3.SA',
  'AALR3.SA',
  'DASA3.SA',
  'FLRY3.SA',
  'HAPV3.SA',
  'PARD3.SA',
  'GNDI3.SA',
  'ODPV3.SA',
  'QUAL3.SA',
  'PNVL3.SA',
  'HYPE3.SA',
  'PFRM3.SA',
  'RADL3.SA'],
 'Tecnologia da Informação': ['POSI3.SA',
  'LINX3.SA',
  'LWSA3.SA',
  'SQIA3.SA',
  'TOTS3.SA'],
 'Utilidade Pública': ['TIET3.SA',
  'ALUP3.SA',
  'CBEE3.SA',
  'CEBR3.SA',
  'CLSC3.SA',
  'GPAR3.SA',
  'CEPE3.SA',
  'CMIG3.SA',
  'CMGD3.SA',
  'CMGT3.SA',
  'CESP3.SA',
  'CEEB3.SA',
  'COCE3.SA',
  'CPLE3.SA',
  'CSRN3.SA',
  'CPFE3.SA',
  'CPFG3.SA',
  'CPFP3.SA',
  'CPRE3.SA',
  'ELET3.SA',
  'ENBR3.SA',
  'ENGI3.SA',
  'ENMT3.SA',
  'ENER3.SA',
  'ENEV3.SA',
  'EGIE3.SA',
  'EQPA3.SA',
  'EQMA3.SA',
  'EQTL3.SA',
  'ESCE3.SA',
  'FGEN3.SA',
  'GEPA3.SA',
  'LIGH3.SA',
  'LIGT3.SA',
  'NEOE3.SA',
  'OMGE3.SA',
  'RNEW3.SA',
  'STEN3.SA',
  'TAEE3.SA',
  'TMPE3.SA',
  'TRPL3.SA',
  'CSMG3.SA',
  'SBSP3.SA',
  'SAPR3.SA',
  'SNST3.SA',
  'CEGR3.SA',
  'CGAS3.SA']}


ativos_fiis = {
    'Logística': [
                  'XPLG11.SA',
                  'HGLG11.SA',
                  'GGRC11.SA',
                  'VILG11.SA',
                  'SDIL11.SA',
                  'ALZR11.SA',
                  'GRLV11.SA'
                  ],
    'Lajes': [
              'HGRE11.SA',
              'BBPO11.SA',
              'EDGA11.SA',
              'RNGO11.SA',
              'CEOC11.SA',
              'XPCM11.SA',
              'XTED11.SA',
              'SPTW11.SA',
              'PRSV11.SA'
              ],
    'Híbridos': [
                 'KNRI11.SA',
                 'BRCR11.SA',
                 'MXRF11.SA',
                 'FIIB11.SA',
                 'FLMA11.SA',
    ],
    'Hotel': [
              'HTMX11.SA'
              ],
    'Papel': [
              'KNCR11.SA',
              'KNIP11.SA',
              'BCFF11.SA',
              'HGCR11.SA',
              'IRDM11.SA',
              'RBRR11.SA',
              'RBRF11.SA',
              'VRTA11.SA',
              'BCRI11.SA'
              ],
    'FOFs': [
              'HFOF11.SA', 
              ],
    'Shoppings': [
                  'HGBS11.SA',
                  'XPML11.SA',
                  'VISC11.SA',
                  'HSML11.SA',
                  'ABCP11.SA',
                  'PQDP11.SA',
                  'MALL11.SA',
                  'FVPQ11.SA',
                  'SHPH11.SA',
    ]
           }

# %%
start = '2019-01-01'
end = '2020-07-30'

# %%
ativos = ativos_fiis
analise_1 = Analise(ativos, start, end)

# %%
analise_1.analise_intrasetorial()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-381fc4e85624> in <module>()
# ----> 1 analise_1.analise_intrasetorial()
#
# ~\Documents\GitHub\valuation\notebooks\analise.py in analise_intrasetorial(self, setores)
#     176             dados_normalizados = self.normalizado(self.dados[setor])
#     177             self.dados[setor] = pd.concat([self.dados[setor], dados_normalizados], axis=1)
# --> 178             self.plot_linhas(dados_normalizados, setor=setor)
#     179
#     180
#
# ~\Documents\GitHub\valuation\notebooks\analise.py in plot_linhas(self, df, setor)
#      93         """
#      94         fig, ax = plt.subplots(figsize=(12, 6))
# ---> 95         df.plot(ax=ax)
#      96         plt.xlabel('Tempo')
#      97         plt.ylabel('Cotação')
#
# ...

# %%
analise_1.analise_intersetorial()
